# %% [markdown]
# # Simple Linear Regression

# %%
import pandas as pd
df=pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# # Splitting Dataset

# %%
x=df[["YearsExperience"]]
y=df['Salary']
x.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.plot(x_train, model.predict(x_train), color="red")
plt.xlabel("Years")
plt.ylabel("Salary")
plt.title("Train Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test)
plt.plot(x_test, model.predict(x_test), color="red")
plt.xlabel("Years")
plt.ylabel("Salary")
plt.title("Test Plot")
plt.show()

# %% [markdown]
# # Evaluation

# %%
model.score(x_train,y_train)
# Out:
# 0.9411949620562126

# %%
model.score(x_test,y_test)
# Out:
# 0.988169515729126

# %% [markdown]
# # Predict the unknown

# %%
model.predict([[5],[8],[11],[15],[19],[25],[29]])
# Out:
# c:\Users\AL AZIZ TECH\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 73342.97478427, 101280.70016446, 129218.42554465, 166468.72605157,
#        203719.02655848, 259594.47731886, 296844.77782577])
